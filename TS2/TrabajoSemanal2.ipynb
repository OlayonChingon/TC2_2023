# %% [markdown]
# # Teoría de los Circuitos 2   <img src="./logo_UTN.svg" align="right" width="150" />
#
# ## Tarea Semanal 1
#
# #### Fabian Villada

# %% [markdown]
# ![TS2enunciado](TS2enunciado.JPG)

# %% [markdown]
# ## Transferencia y componentes del circuito para  $\omega_o = 0$ y Q=3

# %% [markdown]
# ![TS2_1](TS2_1.jpeg)

# %% [markdown]
# ![TS2_2](TS2_2.jpeg)

# %% [markdown]
# ## Normalizacion

# %% [markdown]
# ![TS2_3](TS2_3.jpeg)

# %% [markdown]
# ## Simulacion LTspice

# %% [markdown]
# ![Simulacion1](Simulacion1.JPG)

# %% [markdown]
# ## Pitoneando

# %%
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

w0 = 1
qq = 3
#qq = np.sqrt(2)/2

my_tf = TransferFunction( [w0**2], [1, w0/qq, w0**2] )

bodePlot(my_tf, fig_id=1, filter_description = 'Q={:3.3f}'.format(qq) )

pzmap(my_tf, fig_id=2, filter_description = 'Q={:3.3f}'.format(qq)) #S plane pole/zero plot

GroupDelay(my_tf, fig_id=3, filter_description = 'Q={:3.3f}'.format(qq))
# Out:
# (3,
#  <Axes: title={'center': 'Group delay'}, xlabel='Angular frequency [rad/sec]', ylabel='Group Delay [sec]'>)

# %% [markdown]
# ## Calculamos R1 para $\frac{Vo}{Vi}(\omega=0)=20dB$

# %% [markdown]
# ![TS2_4](TS2_4.JPEG)

# %% [markdown]
# ## Simulacion LTspice para R1=100K

# %% [markdown]
# ![simulacion2](Simulacion2.JPG)
